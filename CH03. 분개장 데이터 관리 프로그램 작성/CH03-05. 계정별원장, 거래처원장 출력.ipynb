# %% [markdown]
# # [ 3-5. 계정별원장, 거래처원장 출력 ]
# ## 1. 계정별원장 데이터 출력

# %%
from journal_file import Journal

# %%
jnl = Journal("분개장_샘플.xlsx")

# %%
jnl.df["계정과목"].unique()
# Out:
# array(['자본금', '보통예금', '객실수입', '고객용품비', '기타영업비용', '판매수수료', '세금과공과',
#        '수도광열비', '급여', '노무용역비', '이자수입'], dtype=object)

# %%
for category in jnl.df["계정과목"].unique():
    print(f"계정과목: {category}\n")
    print(jnl.계정과목(category).df)
    print("\n\n")
# Out:
# 계정과목: 자본금
#
#            일자   전표번호 대분류  중분류  소분류   계정코드 계정과목      적요  차변          대변  구분  거래처명
# 0  2024-01-02  00001  자본  자본금  자본금  00001  자본금  자본금 입금   0  2000000000  차변  패캠호텔
#
#
#
# 계정과목: 보통예금
#
#              일자   전표번호   대분류       중분류   소분류   계정코드  계정과목        적요          차변        대변  구분  거래처명
# 1    2024-01-02  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금    자본금 입금  2000000000         0  대변  하나은행
# 2    2024-01-03  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    33000000         0  차변  하나은행
# 5    2024-01-03  00002  유동자산  현금및현금성자산  보통예금  10300  보통예금  고객용품비 지출           0  20000000  대변  하나은행
# 7    2024-01-03  00003  유동자산  현금및현금성자산  보통예금  10300  보통예금     영업비용A           0  15000000  대변  하나은행
# 8    2024-01-04  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    25000000         0  차변  하나은행
# ..          ...    ...   ...       ...   ...    ...   ...       ...         ...       ...  ..   ...
# 539  2024-05-29  00002  유동자산  현금및현금성자산  보통예금  10300  보통예금   객실판매수수료           0   3600000  대변  하나은행
# 541  2024-05-29  00003  유동자산  현금및현금성자산  보통예금  10300  보통예금   객실판매수수료           0   3200000  대변  하나은행
# 543  2024-05-29  00004  유동자산  현금및현금성자산  보통예금  10300  보통예금  고객용품비 지출           0  16100000  대변  하나은행
# 545  2024-05-29  00005  유동자산  현금및현금성자산  보통예금  10300  보통예금     영업비용E           0  15000000  대변  하나은행
# 546  2024-05-30  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    29000000         0  차변  하나은행
#
# [274 rows x 12 columns]
#
#
#
# 계정과목: 객실수입
#
#              일자   전표번호 대분류 중분류   소분류   계정코드  계정과목     적요  차변        대변  구분   거래처명
# 3    2024-01-03  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  33000000  대변  호텔스닷컴
# 9    2024-01-04  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  25000000  대변   호텔스넷
# 11   2024-01-05  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  30000000  대변  호텔스닷컴
# 13   2024-01-06  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  25000000  대변   호텔스넷
# 15   2024-01-07  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  31000000  대변  호텔스닷컴
# ..          ...    ...  ..  ..   ...    ...   ...    ...  ..       ...  ..    ...
# 531  2024-05-26  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  34000000  대변   호텔스넷
# 533  2024-05-27  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  39000000  대변  호텔스닷컴
# 535  2024-05-28  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  38000000  대변   호텔스넷
# 537  2024-05-29  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  25000000  대변  호텔스닷컴
# 547  2024-05-30  00001  매출  매출  객실수입  40100  객실수입  객실 매출   0  29000000  대변  호텔스닷컴
#
# [149 rows x 12 columns]
#
#
#
# 계정과목: 고객용품비
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목        적요        차변  대변  구분    거래처명
# 4    2024-01-03  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  20000000   0  차변  ABC용품사
# 26   2024-01-10  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# 50   2024-01-17  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  20000000   0  차변  ABC용품사
# 76   2024-01-24  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# 104  2024-01-31  00003  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# ..          ...    ...      ...    ...    ...    ...    ...       ...       ...  ..  ..     ...
# 446  2024-05-03  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출   8400000   0  차변  ABC용품사
# 468  2024-05-10  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22900000   0  차변  ABC용품사
# 492  2024-05-17  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22400000   0  차변  ABC용품사
# 518  2024-05-24  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22600000   0  차변  ABC용품사
# 542  2024-05-29  00004  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  16100000   0  차변  ABC용품사
#
# [25 rows x 12 columns]
#
#
#
# 계정과목: 기타영업비용
#
#              일자   전표번호      대분류   중분류     소분류   계정코드    계정과목     적요        차변  대변  구분 거래처명
# 6    2024-01-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  15000000   0  차변   A사
# 30   2024-01-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  20000000   0  차변   B사
# 52   2024-01-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  18000000   0  차변   A사
# 80   2024-01-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  15000000   0  차변   C사
# 106  2024-01-31  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  20000000   0  차변   C사
# ..          ...    ...      ...   ...     ...    ...     ...    ...       ...  ..  ..  ...
# 448  2024-05-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  19000000   0  차변   A사
# 472  2024-05-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  17000000   0  차변   B사
# 494  2024-05-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  15000000   0  차변   A사
# 522  2024-05-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  23000000   0  차변   C사
# 544  2024-05-29  00005  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  15000000   0  차변   C사
#
# [25 rows x 12 columns]
#
#
#
# 계정과목: 판매수수료
#
#              일자   전표번호      대분류   중분류    소분류   계정코드   계정과목       적요       차변  대변  구분   거래처명
# 16   2024-01-07  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4700000   0  차변  호텔스닷컴
# 20   2024-01-08  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3750000   0  차변   호텔스넷
# 38   2024-01-13  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4550000   0  차변  호텔스닷컴
# 42   2024-01-14  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4600000   0  차변   호텔스넷
# 58   2024-01-19  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3700000   0  차변  호텔스닷컴
# ..          ...    ...      ...   ...    ...    ...    ...      ...      ...  ..  ..    ...
# 502  2024-05-19  00003  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  5650000   0  차변  호텔스닷컴
# 526  2024-05-25  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4900000   0  차변   호텔스넷
# 528  2024-05-25  00003  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4550000   0  차변  호텔스닷컴
# 538  2024-05-29  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3600000   0  차변   호텔스넷
# 540  2024-05-29  00003  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3200000   0  차변  호텔스닷컴
#
# [50 rows x 12 columns]
#
#
#
# 계정과목: 세금과공과
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목     적요        차변  대변  구분   거래처명
# 28   2024-01-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  85000000   0  차변  세금과공과
# 140  2024-02-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  85000000   0  차변  세금과공과
# 248  2024-03-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  97600000   0  차변  세금과공과
# 360  2024-04-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  95300000   0  차변  세금과공과
# 470  2024-05-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  95300000   0  차변  세금과공과
#
#
#
# 계정과목: 수도광열비
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목       적요        차변  대변  구분   거래처명
# 60   2024-01-19  00003  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  41000000   0  차변  수도광열비
# 174  2024-02-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  41000000   0  차변  수도광열비
# 282  2024-03-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  48800000   0  차변  수도광열비
# 394  2024-04-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  47650000   0  차변  수도광열비
# 504  2024-05-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  47650000   0  차변  수도광열비
#
#
#
# 계정과목: 급여
#
#              일자   전표번호      대분류  중분류 소분류   계정코드 계정과목     적요         차변  대변  구분   거래처명
# 68   2024-01-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  170000000   0  차변  종업원급여
# 180  2024-02-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  170000000   0  차변  종업원급여
# 288  2024-03-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
# 400  2024-04-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
# 510  2024-05-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
#
#
#
# 계정과목: 노무용역비
#
#              일자   전표번호      대분류  중분류    소분류   계정코드   계정과목     적요         차변  대변  구분   거래처명
# 78   2024-01-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  170000000   0  차변  노무용역사
# 190  2024-02-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  170000000   0  차변  노무용역사
# 298  2024-03-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  195200000   0  차변  노무용역사
# 410  2024-04-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  190600000   0  차변  노무용역사
# 520  2024-05-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  190600000   0  차변  노무용역사
#
#
#
# 계정과목: 이자수입
#
#              일자   전표번호    대분류    중분류   소분류   계정코드  계정과목       적요  차변       대변  구분  거래처명
# 111  2024-02-02  00001  영업외수익  영업외수익  이자수입  90100  이자수입  정기예금 이자   0  4246575  대변  신한은행
# 219  2024-03-02  00001  영업외수익  영업외수익  이자수입  90100  이자수입  정기예금 이자   0  4246575  대변  신한은행
# 331  2024-04-02  00001  영업외수익  영업외수익  이자수입  90100  이자수입  정기예금 이자   0  4246575  대변  신한은행
# 441  2024-05-02  00001  영업외수익  영업외수익  이자수입  90100  이자수입  정기예금 이자   0  4246575  대변  신한은행

# %% [markdown]
# ## 2. 거래처원장 데이터 출력

# %%
jnl.df["거래처명"].unique()
# Out:
# array(['패캠호텔', '하나은행', '호텔스닷컴', 'ABC용품사', 'A사', '호텔스넷', '세금과공과', 'B사',
#        '수도광열비', '종업원급여', '노무용역사', 'C사', '신한은행'], dtype=object)

# %%
for client in jnl.df["거래처명"].unique():
    print(f"거래처명: {client}\n")
    print(jnl.거래처명(client).df)
    print("\n\n")
# Out:
# 거래처명: 패캠호텔
#
#            일자   전표번호 대분류  중분류  소분류   계정코드 계정과목      적요  차변          대변  구분  거래처명
# 0  2024-01-02  00001  자본  자본금  자본금  00001  자본금  자본금 입금   0  2000000000  차변  패캠호텔
#
#
#
# 거래처명: 하나은행
#
#              일자   전표번호   대분류       중분류   소분류   계정코드  계정과목        적요          차변        대변  구분  거래처명
# 1    2024-01-02  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금    자본금 입금  2000000000         0  대변  하나은행
# 2    2024-01-03  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    33000000         0  차변  하나은행
# 5    2024-01-03  00002  유동자산  현금및현금성자산  보통예금  10300  보통예금  고객용품비 지출           0  20000000  대변  하나은행
# 7    2024-01-03  00003  유동자산  현금및현금성자산  보통예금  10300  보통예금     영업비용A           0  15000000  대변  하나은행
# 8    2024-01-04  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    25000000         0  차변  하나은행
# ..          ...    ...   ...       ...   ...    ...   ...       ...         ...       ...  ..   ...
# 539  2024-05-29  00002  유동자산  현금및현금성자산  보통예금  10300  보통예금   객실판매수수료           0   3600000  대변  하나은행
# 541  2024-05-29  00003  유동자산  현금및현금성자산  보통예금  10300  보통예금   객실판매수수료           0   3200000  대변  하나은행
# 543  2024-05-29  00004  유동자산  현금및현금성자산  보통예금  10300  보통예금  고객용품비 지출           0  16100000  대변  하나은행
# 545  2024-05-29  00005  유동자산  현금및현금성자산  보통예금  10300  보통예금     영업비용E           0  15000000  대변  하나은행
# 546  2024-05-30  00001  유동자산  현금및현금성자산  보통예금  10300  보통예금     객실 매출    29000000         0  차변  하나은행
#
# [270 rows x 12 columns]
#
#
#
# 거래처명: 호텔스닷컴
#
#              일자   전표번호      대분류   중분류    소분류   계정코드   계정과목       적요       차변        대변  구분   거래처명
# 3    2024-01-03  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  33000000  대변  호텔스닷컴
# 11   2024-01-05  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  30000000  대변  호텔스닷컴
# 15   2024-01-07  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  31000000  대변  호텔스닷컴
# 16   2024-01-07  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4700000         0  차변  호텔스닷컴
# 23   2024-01-09  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  31000000  대변  호텔스닷컴
# ..          ...    ...      ...   ...    ...    ...    ...      ...      ...       ...  ..    ...
# 528  2024-05-25  00003  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4550000         0  차변  호텔스닷컴
# 533  2024-05-27  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  39000000  대변  호텔스닷컴
# 537  2024-05-29  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  25000000  대변  호텔스닷컴
# 540  2024-05-29  00003  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3200000         0  차변  호텔스닷컴
# 547  2024-05-30  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  29000000  대변  호텔스닷컴
#
# [104 rows x 12 columns]
#
#
#
# 거래처명: ABC용품사
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목        적요        차변  대변  구분    거래처명
# 4    2024-01-03  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  20000000   0  차변  ABC용품사
# 26   2024-01-10  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# 50   2024-01-17  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  20000000   0  차변  ABC용품사
# 76   2024-01-24  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# 104  2024-01-31  00003  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  15000000   0  차변  ABC용품사
# ..          ...    ...      ...    ...    ...    ...    ...       ...       ...  ..  ..     ...
# 446  2024-05-03  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출   8400000   0  차변  ABC용품사
# 468  2024-05-10  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22900000   0  차변  ABC용품사
# 492  2024-05-17  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22400000   0  차변  ABC용품사
# 518  2024-05-24  00002  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  22600000   0  차변  ABC용품사
# 542  2024-05-29  00004  판매비와관리비  고객용품비  고객용품비  80100  고객용품비  고객용품비 지출  16100000   0  차변  ABC용품사
#
# [25 rows x 12 columns]
#
#
#
# 거래처명: A사
#
#              일자   전표번호      대분류   중분류     소분류   계정코드    계정과목     적요        차변  대변  구분 거래처명
# 6    2024-01-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  15000000   0  차변   A사
# 52   2024-01-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  18000000   0  차변   A사
# 118  2024-02-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  15000000   0  차변   A사
# 164  2024-02-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  18000000   0  차변   A사
# 226  2024-03-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  19000000   0  차변   A사
# 272  2024-03-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  19000000   0  차변   A사
# 338  2024-04-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  19000000   0  차변   A사
# 384  2024-04-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  15000000   0  차변   A사
# 448  2024-05-03  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용A  19000000   0  차변   A사
# 494  2024-05-17  00003  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용C  15000000   0  차변   A사
#
#
#
# 거래처명: 호텔스넷
#
#              일자   전표번호      대분류   중분류    소분류   계정코드   계정과목       적요       차변        대변  구분  거래처명
# 9    2024-01-04  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  25000000  대변  호텔스넷
# 13   2024-01-06  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  25000000  대변  호텔스넷
# 19   2024-01-08  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  25000000  대변  호텔스넷
# 20   2024-01-08  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3750000         0  차변  호텔스넷
# 25   2024-01-10  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  27000000  대변  호텔스넷
# ..          ...    ...      ...   ...    ...    ...    ...      ...      ...       ...  ..   ...
# 517  2024-05-24  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  23000000  대변  호텔스넷
# 526  2024-05-25  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  4900000         0  차변  호텔스넷
# 531  2024-05-26  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  34000000  대변  호텔스넷
# 535  2024-05-28  00001       매출    매출   객실수입  40100   객실수입    객실 매출        0  38000000  대변  호텔스넷
# 538  2024-05-29  00002  판매비와관리비  판매비용  판매수수료  80300  판매수수료  객실판매수수료  3600000         0  차변  호텔스넷
#
# [95 rows x 12 columns]
#
#
#
# 거래처명: 세금과공과
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목     적요        차변  대변  구분   거래처명
# 28   2024-01-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  85000000   0  차변  세금과공과
# 140  2024-02-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  85000000   0  차변  세금과공과
# 248  2024-03-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  97600000   0  차변  세금과공과
# 360  2024-04-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  95300000   0  차변  세금과공과
# 470  2024-05-10  00003  판매비와관리비  기타판관비  세금과공과  80400  세금과공과  세금과공과  95300000   0  차변  세금과공과
#
#
#
# 거래처명: B사
#
#              일자   전표번호      대분류   중분류     소분류   계정코드    계정과목     적요        차변  대변  구분 거래처명
# 30   2024-01-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  20000000   0  차변   B사
# 142  2024-02-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  20000000   0  차변   B사
# 250  2024-03-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  24000000   0  차변   B사
# 362  2024-04-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  17000000   0  차변   B사
# 472  2024-05-10  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용B  17000000   0  차변   B사
#
#
#
# 거래처명: 수도광열비
#
#              일자   전표번호      대분류    중분류    소분류   계정코드   계정과목       적요        차변  대변  구분   거래처명
# 60   2024-01-19  00003  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  41000000   0  차변  수도광열비
# 174  2024-02-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  41000000   0  차변  수도광열비
# 282  2024-03-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  48800000   0  차변  수도광열비
# 394  2024-04-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  47650000   0  차변  수도광열비
# 504  2024-05-19  00004  판매비와관리비  기타판관비  수도광열비  80500  수도광열비  수도광열비 등  47650000   0  차변  수도광열비
#
#
#
# 거래처명: 종업원급여
#
#              일자   전표번호      대분류  중분류 소분류   계정코드 계정과목     적요         차변  대변  구분   거래처명
# 68   2024-01-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  170000000   0  차변  종업원급여
# 180  2024-02-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  170000000   0  차변  종업원급여
# 288  2024-03-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
# 400  2024-04-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
# 510  2024-05-21  00002  판매비와관리비  인건비  급여  80600   급여  종업원급여  180000000   0  차변  종업원급여
#
#
#
# 거래처명: 노무용역사
#
#              일자   전표번호      대분류  중분류    소분류   계정코드   계정과목     적요         차변  대변  구분   거래처명
# 78   2024-01-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  170000000   0  차변  노무용역사
# 190  2024-02-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  170000000   0  차변  노무용역사
# 298  2024-03-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  195200000   0  차변  노무용역사
# 410  2024-04-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  190600000   0  차변  노무용역사
# 520  2024-05-24  00003  판매비와관리비  인건비  노무용역비  80700  노무용역비  노무용역비  190600000   0  차변  노무용역사
#
#
#
# 거래처명: C사
#
#              일자   전표번호      대분류   중분류     소분류   계정코드    계정과목     적요        차변  대변  구분 거래처명
# 80   2024-01-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  15000000   0  차변   C사
# 106  2024-01-31  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  20000000   0  차변   C사
# 192  2024-02-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  15000000   0  차변   C사
# 214  2024-02-29  00005  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  20000000   0  차변   C사
# 300  2024-03-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  16000000   0  차변   C사
# 322  2024-03-29  00005  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  16000000   0  차변   C사
# 412  2024-04-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  23000000   0  차변   C사
# 434  2024-04-29  00005  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  15000000   0  차변   C사
# 522  2024-05-24  00004  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용D  23000000   0  차변   C사
# 544  2024-05-29  00005  판매비와관리비  판매비용  기타영업비용  80200  기타영업비용  영업비용E  15000000   0  차변   C사
#
#
#
# 거래처명: 신한은행
#
#              일자   전표번호    대분류       중분류   소분류   계정코드  계정과목       적요       차변       대변  구분  거래처명
# 110  2024-02-02  00001   유동자산  현금및현금성자산  보통예금  10300  보통예금  정기예금 이자  4246575        0  차변  신한은행
# 111  2024-02-02  00001  영업외수익     영업외수익  이자수입  90100  이자수입  정기예금 이자        0  4246575  대변  신한은행
# 218  2024-03-02  00001   유동자산  현금및현금성자산  보통예금  10300  보통예금  정기예금 이자  4246575        0  차변  신한은행
# 219  2024-03-02  00001  영업외수익     영업외수익  이자수입  90100  이자수입  정기예금 이자        0  4246575  대변  신한은행
# 330  2024-04-02  00001   유동자산  현금및현금성자산  보통예금  10300  보통예금  정기예금 이자  4246575        0  차변  신한은행
# 331  2024-04-02  00001  영업외수익     영업외수익  이자수입  90100  이자수입  정기예금 이자        0  4246575  대변  신한은행
# 440  2024-05-02  00001   유동자산  현금및현금성자산  보통예금  10300  보통예금  정기예금 이자  4246575        0  차변  신한은행
# 441  2024-05-02  00001  영업외수익     영업외수익  이자수입  90100  이자수입  정기예금 이자        0  4246575  대변  신한은행

# %% [markdown]
# ## 3. 계정별원장 엑셀 출력

# %%
from openpyxl import Workbook

# 워크북 생성
wb = Workbook()

# 기본적으로 생성되는 활성 시트 제거
default_sheet = wb.active
wb.remove(default_sheet)


# 각 카테고리에 대해 시트 생성 및 데이터 쓰기
for category in jnl.df["계정과목"].unique():
    # category 이름으로 신규 시트 생성
    ws = wb.create_sheet(title=category)

    # 시트에 첫번째 셀에 category 이름 출력
    ws.append([category])
    #ws.cell(row=1, column=1, value=category)

    # 한칸 띄우기
    ws.append([])

    # 컬럼명 출력
    ws.append(tuple(jnl.df.columns))

    # category에 해당하는 계정과목 DataFrame에 대하여 한행씩 row 변수에 대입
    for r_idx, row in enumerate(
            jnl.계정과목(category).df.itertuples(index=False), 
            start=4
        ):
        # itertuples 메서드 대신 iterrows 메서드를 사용해도 되며 차이점은 반복 속도임
        # (itertuples 메서드가 iterrows 메서드 보다 빠르게 작동)

        # 한 행(row)에 대하여 컬럼번호(c_idx)를 증가시키면서 한 셀씩 출력
        for c_idx, value in enumerate(row, start=1):
            ws.cell(row=r_idx, column=c_idx, value=value)

# 최종 완성된 파일 엑셀 저장
wb.save("계정별원장.xlsx")

# %% [markdown]
# ## 4. 거래처원장 엑셀 출력

# %%
from openpyxl import Workbook

# 워크북 생성
wb = Workbook()

# 기본적으로 생성되는 활성 시트 제거
default_sheet = wb.active
wb.remove(default_sheet)


# 각 카테고리에 대해 시트 생성 및 데이터 쓰기
for client in jnl.df["거래처명"].unique():
    # client 이름으로 신규 시트 생성
    ws = wb.create_sheet(title=client)

    # 시트에 첫번째 셀에 client 이름 출력
    ws.append([client])
    #ws.cell(row=1, column=1, value=client)

    # 한칸 띄우기
    ws.append([])

    # 컬럼명 출력
    ws.append(tuple(jnl.df.columns))

    # client에 해당하는 거래처명 DataFrame에 대하여 한행씩 row 변수에 대입
    for r_idx, row in enumerate(
            jnl.거래처명(client).df.itertuples(index=False), 
            start=4
        ):
        # itertuples 메서드 대신 iterrows 메서드를 사용해도 되며 차이점은 반복 속도임
        # (itertuples 메서드가 iterrows 메서드 보다 빠르게 작동)

        # 한 행(row)에 대하여 컬럼번호(c_idx)를 증가시키면서 한 셀씩 출력
        for c_idx, value in enumerate(row, start=1):
            ws.cell(row=r_idx, column=c_idx, value=value)

# 최종 완성된 파일 엑셀 저장
wb.save("거래처원장.xlsx")
